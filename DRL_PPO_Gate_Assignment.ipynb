# %%
import pandas as pd
import numpy as np
import random
from datetime import datetime, timedelta

# Parameters
NUM_FLIGHTS = 100
NUM_GATES = 25
AIRLINES = ['MU', 'CA', 'CZ', 'HU', 'ZH', 'HO']
TERMINALS = ['T1', 'T2']
AIRCRAFT_TYPES = ['A320', 'A330', 'B737', 'B777']
DELAY_PROB = 0.5
BUFFER_MIN = 20  # buffer time before and after usage

np.random.seed(42)

# Generate gate info
gate_list = []
for i in range(NUM_GATES):
    gate_id = f"G{i+1:02d}"
    is_bridge = np.random.choice([1, 0], p=[0.7, 0.3])
    gate = {
        "Gate_ID": gate_id,
        "Terminal": random.choice(TERMINALS),
        "Is_Bridge": is_bridge,
        "Max_Aircraft": random.choice(AIRCRAFT_TYPES)
    }
    gate_list.append(gate)
gates_df = pd.DataFrame(gate_list)

# Prepare remote stands for non-bridge gates
remote_stands = [f"R{20+i:02d}" for i in range(NUM_GATES)]  # R20–R44
bridge_gates = gates_df[gates_df["Is_Bridge"] == 1]["Gate_ID"].tolist()
remote_gate_map = dict(zip(gates_df[gates_df["Is_Bridge"] == 0]["Gate_ID"], remote_stands))

# Generate flights
flight_list = []
base_time = datetime(2025, 8, 21, 6, 0, 0)
for _ in range(NUM_FLIGHTS):
    arr_time = base_time + timedelta(minutes=np.random.randint(0, 720))
    dep_time = arr_time + timedelta(minutes=np.random.randint(40, 90))
    airline = random.choice(AIRLINES)
    flight = {
        "Flight_ID": f"{airline}{np.random.randint(1000, 9999)}",
        "Aircraft_Type": random.choice(AIRCRAFT_TYPES),
        "Scheduled_ARR": arr_time,
        "Scheduled_DEP": dep_time,
        "Airline": airline,
        "Terminal": random.choice(TERMINALS),
        "Is_International": np.random.choice([0, 1], p=[0.8, 0.2]),
        "Delay_MIN": np.random.randint(10, 120) if np.random.rand() < DELAY_PROB else 0,
    }
    flight_list.append(flight)
flights_df = pd.DataFrame(flight_list)

# Compute actual arrival time
flights_df["Actual_ARR"] = flights_df["Scheduled_ARR"] + pd.to_timedelta(flights_df["Delay_MIN"], unit='m')

# Sort flights by arrival time for sequential assignment
flights_df = flights_df.sort_values("Actual_ARR").reset_index(drop=True)

# Track stand usage: {stand_id: [(start_time, end_time), ...]}
stand_usage = {}

# Assign gates and stands
assigned_gates = []
assigned_stands = []

for idx, row in flights_df.iterrows():
    # Use scheduled time for advance planning
    arr = row["Scheduled_ARR"] - timedelta(minutes=BUFFER_MIN)
    dep = row["Scheduled_DEP"] + timedelta(minutes=BUFFER_MIN)

    assigned = False
    for _, gate_row in gates_df.iterrows():
        gate_id = gate_row["Gate_ID"]
        is_bridge = gate_row["Is_Bridge"]

        # Determine stand ID
        stand_id = gate_id if is_bridge else remote_gate_map[gate_id]

        # Check for time conflicts
        usage = stand_usage.get(stand_id, [])
        conflict = any((arr < end and dep > start) for start, end in usage)
        if not conflict:
            assigned_gates.append(gate_id)
            assigned_stands.append(stand_id)
            stand_usage.setdefault(stand_id, []).append((arr, dep))
            assigned = True
            break

    if not assigned:
        assigned_gates.append(None)
        assigned_stands.append(None)
        print(f"❌ Flight {row['Flight_ID']} cannot be assigned.")

# Add assignments to DataFrame
flights_df["Assigned_Gate"] = assigned_gates
flights_df["Assigned_Stand"] = assigned_stands

# Final output
output_cols = [
    "Flight_ID", "Aircraft_Type", "Airline", "Is_International",
    "Scheduled_ARR", "Scheduled_DEP", "Delay_MIN", "Actual_ARR",
    "Assigned_Gate", "Assigned_Stand"
]
print(flights_df[output_cols].head(10))
# Out:
#   Flight_ID Aircraft_Type Airline  Is_International       Scheduled_ARR  \
# 0    CA4157          A330      CA                 1 2025-08-21 06:35:00
# 1    CA4420          A320      CA                 0 2025-08-21 06:36:00
# 2    ZH5380          A330      ZH                 0 2025-08-21 06:42:00
# 3    CA3491          A330      CA                 0 2025-08-21 06:53:00
# 4    MU7316          A330      MU                 0 2025-08-21 06:57:00
# 5    HO1728          B737      HO                 0 2025-08-21 07:01:00
# 6    CA5491          B737      CA                 0 2025-08-21 07:08:00
# 7    HU9392          B777      HU                 0 2025-08-21 06:27:00
# 8    HO2571          B777      HO                 0 2025-08-21 07:38:00
# 9    HU8390          A330      HU                 0 2025-08-21 07:39:00
#
#         Scheduled_DEP  Delay_MIN          Actual_ARR Assigned_Gate  \
# 0 2025-08-21 07:27:00          0 2025-08-21 06:35:00           G01
# 1 2025-08-21 07:39:00          0 2025-08-21 06:36:00           G02
# 2 2025-08-21 08:05:00         11 2025-08-21 06:53:00           G03
# 3 2025-08-21 08:15:00          0 2025-08-21 06:53:00           G04
# 4 2025-08-21 08:20:00          0 2025-08-21 06:57:00           G05
# 5 2025-08-21 08:00:00          0 2025-08-21 07:01:00           G06
# 6 2025-08-21 08:22:00          0 2025-08-21 07:08:00           G07
# 7 2025-08-21 07:13:00         57 2025-08-21 07:24:00           G08
# 8 2025-08-21 09:05:00          0 2025-08-21 07:38:00           G09
# 9 2025-08-21 08:52:00          0 2025-08-21 07:39:00           G10
#
#   Assigned_Stand
# 0            G01
# 1            R20
# 2            R21
# 3            G04
# 4            G05
# 5            G06
# 6            G07
# 7            R22
# 8            G09
# 9            R23

# %%
# Select and rename relevant columns for export
export_df = flights_df[[
    "Flight_ID", "Aircraft_Type", "Airline", "Is_International",
    "Scheduled_ARR", "Scheduled_DEP", "Delay_MIN", "Actual_ARR",
    "Assigned_Gate", "Assigned_Stand"
]].copy()

# Sort by Scheduled_ARR for easier viewing
export_df.sort_values("Scheduled_ARR", inplace=True)

# Save to CSV
export_df.to_csv("simulated_flight_gate_assignment.csv", index=False, encoding="utf-8-sig")

print("Exported to simulated_flight_gate_assignment.csv")
# Out:
# Exported to simulated_flight_gate_assignment.csv

# %%
from collections import Counter

usage_counter = Counter(assigned_stands)
for stand, count in sorted(usage_counter.items()):
    print(f"{stand}: used {count} times")

unassigned = sum(pd.isna(flights_df["Assigned_Stand"]))
print(f"\nUnassigned flights: {unassigned}")
# Out:
# G01: used 8 times
# G04: used 6 times
# G05: used 5 times
# G06: used 6 times
# G07: used 5 times
# G09: used 4 times
# G11: used 5 times
# G14: used 4 times
# G15: used 3 times
# G16: used 4 times
# G17: used 3 times
# G18: used 3 times
# G19: used 3 times
# G20: used 2 times
# G21: used 2 times
# G22: used 3 times
# G23: used 2 times
# G24: used 1 times
# G25: used 1 times
# R20: used 6 times
# R21: used 5 times
# R22: used 6 times
# R23: used 4 times
# R24: used 5 times
# R25: used 4 times
#
# Unassigned flights: 0

# %%
# !pip install gymnasium
# !pip install stable-baselines3[extra]
# Out:
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.12/dist-packages (1.2.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (0.0.4)
# Collecting stable-baselines3[extra]
#   Downloading stable_baselines3-2.7.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: gymnasium<1.3.0,>=0.29.1 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (1.2.0)
# Requirement already satisfied: numpy<3.0,>=1.20 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (2.0.2)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (2.8.0+cu126)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (3.1.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (3.10.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (4.12.0.88)
# Requirement already satisfied: pygame in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (2.6.1)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (2.19.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (5.9.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (4.67.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (13.9.4)
# Requirement already satisfied: ale-py>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (0.11.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from stable-baselines3[extra]) (11.3.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium<1.3.0,>=0.29.1->stable-baselines3[extra]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium<1.3.0,>=0.29.1->stable-baselines3[extra]) (0.0.4)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.74.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.8.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (25.0)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (5.29.5)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (75.2.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.1.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.19.1)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3[extra]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3[extra]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3[extra]) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3[extra]) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3[extra]) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3[extra]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3[extra]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3[extra]) (2025.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->stable-baselines3[extra]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->stable-baselines3[extra]) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (3.0.2)
# Downloading stable_baselines3-2.7.0-py3-none-any.whl (187 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.2/187.2 kB 3.4 MB/s eta 0:00:00
# Installing collected packages: stable-baselines3
# Successfully installed stable-baselines3-2.7.0

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import pandas as pd
from datetime import timedelta


class RealTimeGateEnv(gym.Env):
    """
    Environment for real-time gate reallocation based on delays.
    Each step processes a flight; the agent decides to reassign it or not.
    """
    def __init__(self, flights_df, gates_df, buffer_min=20):
        super().__init__()
        self.flights_df = flights_df.copy()
        self.gates_df = gates_df.copy()
        self.buffer_min = buffer_min
        self.num_gates = len(gates_df)
        self.num_flights = len(flights_df)

        self.action_space = spaces.Discrete(self.num_gates + 1)  # 0~n-1 = reassign to gate; n = keep original
        self.observation_space = spaces.Dict({
            "flight_features": spaces.Box(low=0, high=1, shape=(6,), dtype=np.float32),
            "gate_mask": spaces.MultiBinary(self.num_gates)
        })

        self.remote_gate_map = self._build_remote_gate_map()
        self.current_idx = 0
        self.stand_usage = {g: [] for g in gates_df["Gate_ID"]}

    def _build_remote_gate_map(self):
        # Map non-bridge gates to remote stand IDs
        remote_stands = [f"R{20+i:02d}" for i in range(self.num_gates)]
        return dict(zip(self.gates_df[self.gates_df["Is_Bridge"] == 0]["Gate_ID"], remote_stands))

    def reset(self, *, seed=None, options=None):
        super().reset(seed=seed)
        self.current_idx = 0
        self.stand_usage = {g: [] for g in self.gates_df["Gate_ID"]}
        return self._get_obs(), {}

    def _get_obs(self):
        if self.current_idx >= self.num_flights:
            return {
                "flight_features": np.zeros(6, dtype=np.float32),
                "gate_mask": np.zeros(self.num_gates, dtype=np.int8)
            }

        row = self.flights_df.iloc[self.current_idx]
        arr = row["Actual_ARR"] - timedelta(minutes=self.buffer_min)
        dep = row["Scheduled_DEP"] + timedelta(minutes=self.buffer_min)

        gate_mask = []
        for _, gate_row in self.gates_df.iterrows():
            gate_id = gate_row["Gate_ID"]
            usage = self.stand_usage[gate_id]
            conflict = any((arr < end and dep > start) for start, end in usage)
            gate_mask.append(0 if conflict else 1)

        # Features: arrival, dep, delay, intl, wide-body, original_gate_id
        arr_min = row["Actual_ARR"].hour * 60 + row["Actual_ARR"].minute
        dep_min = row["Scheduled_DEP"].hour * 60 + row["Scheduled_DEP"].minute
        features = np.array([
            arr_min / 1440,
            dep_min / 1440,
            row["Delay_MIN"] / 180,
            row["Is_International"],
            int(row["Aircraft_Type"] in ["A330", "B777"]),
            0.0 if pd.isna(row["Assigned_Gate"]) else int(row["Assigned_Gate"][1:]) / self.num_gates
        ], dtype=np.float32)

        return {
            "flight_features": features,
            "gate_mask": np.array(gate_mask, dtype=np.int8)
        }

    def step(self, action):
        info = {}
        if self.current_idx >= self.num_flights:
            return self._get_obs(), 0.0, True, True, info

        row = self.flights_df.iloc[self.current_idx]
        arr = row["Actual_ARR"] - timedelta(minutes=self.buffer_min)
        dep = row["Scheduled_DEP"] + timedelta(minutes=self.buffer_min)

        assigned_gate = row["Assigned_Gate"]
        gate_id = None
        reward = 0

        if action == self.num_gates:
            # Keep original gate
            gate_id = assigned_gate
        else:
            gate_id = self.gates_df.iloc[action]["Gate_ID"]

        # Check conflict
        usage = self.stand_usage.get(gate_id, [])
        conflict = any((arr < end and dep > start) for start, end in usage)

        if conflict or pd.isna(gate_id):
            reward = -5
        else:
            reward = 1 if gate_id == assigned_gate else 0.5  # encourage reuse
            self.stand_usage[gate_id].append((arr, dep))

        self.current_idx += 1
        terminated = self.current_idx >= self.num_flights
        truncated = False
        return self._get_obs(), reward, terminated, truncated, info

    def render(self):
        print(f"Flight {self.current_idx}")

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv

# Create and wrap environment
env = RealTimeGateEnv(flights_df, gates_df)
vec_env = DummyVecEnv([lambda: env])

# Train agent
model = PPO("MultiInputPolicy", vec_env, learning_rate=1e-3, n_steps=1024, batch_size=64, gae_lambda=0.95, clip_range=0.2, verbose=1)
model.learn(total_timesteps=100000)
# Out:
# Using cpu device
# -----------------------------
# | time/              |      |
# |    fps             | 279  |
# |    iterations      | 1    |
# |    time_elapsed    | 3    |
# |    total_timesteps | 1024 |
# -----------------------------
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:151: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 213         |
# |    iterations           | 2           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.022668332 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.25       |
# |    explained_variance   | -0.0161     |
# |    learning_rate        | 0.001       |
# |    loss                 | 23.7        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0484     |
# |    value_loss           | 90          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 211         |
# |    iterations           | 3           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.007818433 |
# |    clip_fraction        | 0.0171      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.24       |
# |    explained_variance   | -0.000312   |
# |    learning_rate        | 0.001       |
# |    loss                 | 58          |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0167     |
# |    value_loss           | 140         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 216         |
# |    iterations           | 4           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.026227856 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.22       |
# |    explained_variance   | -0.000357   |
# |    learning_rate        | 0.001       |
# |    loss                 | 52.1        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0267     |
# |    value_loss           | 147         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 210        |
# |    iterations           | 5          |
# |    time_elapsed         | 24         |
# |    total_timesteps      | 5120       |
# | train/                  |            |
# |    approx_kl            | 0.03109526 |
# |    clip_fraction        | 0.256      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.2       |
# |    explained_variance   | -6.44e-05  |
# |    learning_rate        | 0.001      |
# |    loss                 | 67.1       |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0335    |
# |    value_loss           | 163        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 214         |
# |    iterations           | 6           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.023367934 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.18       |
# |    explained_variance   | -2.74e-05   |
# |    learning_rate        | 0.001       |
# |    loss                 | 110         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.038      |
# |    value_loss           | 196         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 206        |
# |    iterations           | 7          |
# |    time_elapsed         | 34         |
# |    total_timesteps      | 7168       |
# | train/                  |            |
# |    approx_kl            | 0.02626411 |
# |    clip_fraction        | 0.278      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.17      |
# |    explained_variance   | -1.07e-05  |
# |    learning_rate        | 0.001      |
# |    loss                 | 100        |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0404    |
# |    value_loss           | 175        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 208        |
# |    iterations           | 8          |
# |    time_elapsed         | 39         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.02252656 |
# |    clip_fraction        | 0.255      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.14      |
# |    explained_variance   | -1.57e-05  |
# |    learning_rate        | 0.001      |
# |    loss                 | 109        |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.0457    |
# |    value_loss           | 188        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 207         |
# |    iterations           | 9           |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.024365483 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.12       |
# |    explained_variance   | -3.93e-06   |
# |    learning_rate        | 0.001       |
# |    loss                 | 103         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0508     |
# |    value_loss           | 211         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 206         |
# |    iterations           | 10          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.037327737 |
# |    clip_fraction        | 0.29        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.12       |
# |    explained_variance   | -1.38e-05   |
# |    learning_rate        | 0.001       |
# |    loss                 | 83.7        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0382     |
# |    value_loss           | 191         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 208         |
# |    iterations           | 11          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.039251808 |
# |    clip_fraction        | 0.303       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.1        |
# |    explained_variance   | -3.1e-06    |
# |    learning_rate        | 0.001       |
# |    loss                 | 107         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0423     |
# |    value_loss           | 186         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 207         |
# |    iterations           | 12          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.028078774 |
# |    clip_fraction        | 0.279       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.09       |
# |    explained_variance   | -2.86e-06   |
# |    learning_rate        | 0.001       |
# |    loss                 | 95.7        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0466     |
# |    value_loss           | 196         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 206         |
# |    iterations           | 13          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.027284529 |
# |    clip_fraction        | 0.29        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.06       |
# |    explained_variance   | -4.65e-06   |
# |    learning_rate        | 0.001       |
# |    loss                 | 107         |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0477     |
# |    value_loss           | 169         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 207        |
# |    iterations           | 14         |
# |    time_elapsed         | 69         |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.02188034 |
# |    clip_fraction        | 0.235      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.06      |
# |    explained_variance   | -7.87e-06  |
# |    learning_rate        | 0.001      |
# |    loss                 | 62.7       |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.044     |
# |    value_loss           | 176        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 15          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.027020698 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.04       |
# |    explained_variance   | -5.13e-06   |
# |    learning_rate        | 0.001       |
# |    loss                 | 67.4        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0365     |
# |    value_loss           | 161         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 16          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.025060399 |
# |    clip_fraction        | 0.289       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.04       |
# |    explained_variance   | -2.98e-06   |
# |    learning_rate        | 0.001       |
# |    loss                 | 62          |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0446     |
# |    value_loss           | 166         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 17          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 17408       |
# | train/                  |             |
# |    approx_kl            | 0.022749187 |
# |    clip_fraction        | 0.27        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.01       |
# |    explained_variance   | -1.79e-06   |
# |    learning_rate        | 0.001       |
# |    loss                 | 66.1        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0505     |
# |    value_loss           | 177         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 204        |
# |    iterations           | 18         |
# |    time_elapsed         | 90         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.01402189 |
# |    clip_fraction        | 0.208      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.01      |
# |    explained_variance   | -1.07e-06  |
# |    learning_rate        | 0.001      |
# |    loss                 | 66.6       |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0516    |
# |    value_loss           | 166        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 19          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 0.010694608 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3          |
# |    explained_variance   | 0.0529      |
# |    learning_rate        | 0.001       |
# |    loss                 | 45.2        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.044      |
# |    value_loss           | 119         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 203         |
# |    iterations           | 20          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009289908 |
# |    clip_fraction        | 0.0773      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.99       |
# |    explained_variance   | 0.162       |
# |    learning_rate        | 0.001       |
# |    loss                 | 41.2        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0369     |
# |    value_loss           | 85.9        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 204          |
# |    iterations           | 21           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 21504        |
# | train/                  |              |
# |    approx_kl            | 0.0079820575 |
# |    clip_fraction        | 0.0489       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.99        |
# |    explained_variance   | 0.383        |
# |    learning_rate        | 0.001        |
# |    loss                 | 31.9         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.0289      |
# |    value_loss           | 74.8         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 202        |
# |    iterations           | 22         |
# |    time_elapsed         | 111        |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.00868121 |
# |    clip_fraction        | 0.0633     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.99      |
# |    explained_variance   | 0.556      |
# |    learning_rate        | 0.001      |
# |    loss                 | 18.3       |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.0325    |
# |    value_loss           | 52.7       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 202         |
# |    iterations           | 23          |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 23552       |
# | train/                  |             |
# |    approx_kl            | 0.009152919 |
# |    clip_fraction        | 0.0598      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.98       |
# |    explained_variance   | 0.621       |
# |    learning_rate        | 0.001       |
# |    loss                 | 18.9        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.031      |
# |    value_loss           | 49.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 202         |
# |    iterations           | 24          |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008939004 |
# |    clip_fraction        | 0.0648      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.97       |
# |    explained_variance   | 0.662       |
# |    learning_rate        | 0.001       |
# |    loss                 | 18.8        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.034      |
# |    value_loss           | 42          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 201         |
# |    iterations           | 25          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.009939446 |
# |    clip_fraction        | 0.0811      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.95       |
# |    explained_variance   | 0.708       |
# |    learning_rate        | 0.001       |
# |    loss                 | 17.4        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0388     |
# |    value_loss           | 38.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 201         |
# |    iterations           | 26          |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.009877995 |
# |    clip_fraction        | 0.0747      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.95       |
# |    explained_variance   | 0.754       |
# |    learning_rate        | 0.001       |
# |    loss                 | 8.06        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0356     |
# |    value_loss           | 28.3        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 201        |
# |    iterations           | 27         |
# |    time_elapsed         | 137        |
# |    total_timesteps      | 27648      |
# | train/                  |            |
# |    approx_kl            | 0.01110682 |
# |    clip_fraction        | 0.103      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.94      |
# |    explained_variance   | 0.707      |
# |    learning_rate        | 0.001      |
# |    loss                 | 9.95       |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.0416    |
# |    value_loss           | 28.2       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 202          |
# |    iterations           | 28           |
# |    time_elapsed         | 141          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0132767465 |
# |    clip_fraction        | 0.113        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.91        |
# |    explained_variance   | 0.724        |
# |    learning_rate        | 0.001        |
# |    loss                 | 9.66         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.0453      |
# |    value_loss           | 25.6         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 203         |
# |    iterations           | 29          |
# |    time_elapsed         | 146         |
# |    total_timesteps      | 29696       |
# | train/                  |             |
# |    approx_kl            | 0.010617033 |
# |    clip_fraction        | 0.0859      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.88       |
# |    explained_variance   | 0.748       |
# |    learning_rate        | 0.001       |
# |    loss                 | 10.9        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0398     |
# |    value_loss           | 26.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 202         |
# |    iterations           | 30          |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.012015458 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.89       |
# |    explained_variance   | 0.744       |
# |    learning_rate        | 0.001       |
# |    loss                 | 10.3        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0457     |
# |    value_loss           | 25.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 203         |
# |    iterations           | 31          |
# |    time_elapsed         | 156         |
# |    total_timesteps      | 31744       |
# | train/                  |             |
# |    approx_kl            | 0.013280812 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.9        |
# |    explained_variance   | 0.766       |
# |    learning_rate        | 0.001       |
# |    loss                 | 12.7        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0496     |
# |    value_loss           | 25.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 203         |
# |    iterations           | 32          |
# |    time_elapsed         | 161         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.013496887 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.88       |
# |    explained_variance   | 0.717       |
# |    learning_rate        | 0.001       |
# |    loss                 | 15.2        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0468     |
# |    value_loss           | 31.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 203         |
# |    iterations           | 33          |
# |    time_elapsed         | 166         |
# |    total_timesteps      | 33792       |
# | train/                  |             |
# |    approx_kl            | 0.016746905 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.87       |
# |    explained_variance   | 0.649       |
# |    learning_rate        | 0.001       |
# |    loss                 | 10.5        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0538     |
# |    value_loss           | 27.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 203         |
# |    iterations           | 34          |
# |    time_elapsed         | 171         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.016505446 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.85       |
# |    explained_variance   | 0.726       |
# |    learning_rate        | 0.001       |
# |    loss                 | 11.3        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0559     |
# |    value_loss           | 25.6        |
# -----------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 203      |
# |    iterations           | 35       |
# |    time_elapsed         | 176      |
# |    total_timesteps      | 35840    |
# | train/                  |          |
# |    approx_kl            | 0.018075 |
# |    clip_fraction        | 0.192    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -2.84    |
# |    explained_variance   | 0.629    |
# |    learning_rate        | 0.001    |
# |    loss                 | 11.1     |
# |    n_updates            | 340      |
# |    policy_gradient_loss | -0.0575  |
# |    value_loss           | 25.6     |
# --------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 203         |
# |    iterations           | 36          |
# |    time_elapsed         | 180         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.022694957 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | 0.622       |
# |    learning_rate        | 0.001       |
# |    loss                 | 9.3         |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0611     |
# |    value_loss           | 20          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 204         |
# |    iterations           | 37          |
# |    time_elapsed         | 185         |
# |    total_timesteps      | 37888       |
# | train/                  |             |
# |    approx_kl            | 0.023222517 |
# |    clip_fraction        | 0.256       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.79       |
# |    explained_variance   | 0.675       |
# |    learning_rate        | 0.001       |
# |    loss                 | 5.97        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0655     |
# |    value_loss           | 17.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 203         |
# |    iterations           | 38          |
# |    time_elapsed         | 190         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.022218442 |
# |    clip_fraction        | 0.258       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.79       |
# |    explained_variance   | 0.685       |
# |    learning_rate        | 0.001       |
# |    loss                 | 10.1        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0667     |
# |    value_loss           | 24.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 203         |
# |    iterations           | 39          |
# |    time_elapsed         | 195         |
# |    total_timesteps      | 39936       |
# | train/                  |             |
# |    approx_kl            | 0.027933458 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.75       |
# |    explained_variance   | 0.469       |
# |    learning_rate        | 0.001       |
# |    loss                 | 9.56        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0637     |
# |    value_loss           | 23.1        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 203        |
# |    iterations           | 40         |
# |    time_elapsed         | 201        |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.03479714 |
# |    clip_fraction        | 0.327      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.73      |
# |    explained_variance   | 0.593      |
# |    learning_rate        | 0.001      |
# |    loss                 | 6.4        |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.0711    |
# |    value_loss           | 16.5       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 203         |
# |    iterations           | 41          |
# |    time_elapsed         | 205         |
# |    total_timesteps      | 41984       |
# | train/                  |             |
# |    approx_kl            | 0.030109942 |
# |    clip_fraction        | 0.316       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.71       |
# |    explained_variance   | 0.58        |
# |    learning_rate        | 0.001       |
# |    loss                 | 10.4        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0733     |
# |    value_loss           | 19.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 204         |
# |    iterations           | 42          |
# |    time_elapsed         | 210         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.029222853 |
# |    clip_fraction        | 0.318       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.7        |
# |    explained_variance   | 0.618       |
# |    learning_rate        | 0.001       |
# |    loss                 | 5.93        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0717     |
# |    value_loss           | 17.2        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 204        |
# |    iterations           | 43         |
# |    time_elapsed         | 215        |
# |    total_timesteps      | 44032      |
# | train/                  |            |
# |    approx_kl            | 0.03127799 |
# |    clip_fraction        | 0.318      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.68      |
# |    explained_variance   | 0.608      |
# |    learning_rate        | 0.001      |
# |    loss                 | 9.49       |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.0742    |
# |    value_loss           | 19.8       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 204         |
# |    iterations           | 44          |
# |    time_elapsed         | 219         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.036975108 |
# |    clip_fraction        | 0.383       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.64       |
# |    explained_variance   | 0.496       |
# |    learning_rate        | 0.001       |
# |    loss                 | 4.74        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.076      |
# |    value_loss           | 16.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 45          |
# |    time_elapsed         | 224         |
# |    total_timesteps      | 46080       |
# | train/                  |             |
# |    approx_kl            | 0.034595132 |
# |    clip_fraction        | 0.345       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.62       |
# |    explained_variance   | 0.443       |
# |    learning_rate        | 0.001       |
# |    loss                 | 7.77        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0722     |
# |    value_loss           | 20          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 46          |
# |    time_elapsed         | 229         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.033131264 |
# |    clip_fraction        | 0.327       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.61       |
# |    explained_variance   | 0.584       |
# |    learning_rate        | 0.001       |
# |    loss                 | 7.41        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0731     |
# |    value_loss           | 17.3        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 205        |
# |    iterations           | 47         |
# |    time_elapsed         | 233        |
# |    total_timesteps      | 48128      |
# | train/                  |            |
# |    approx_kl            | 0.04689648 |
# |    clip_fraction        | 0.405      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.61      |
# |    explained_variance   | 0.512      |
# |    learning_rate        | 0.001      |
# |    loss                 | 5.58       |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.0787    |
# |    value_loss           | 17.7       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 205        |
# |    iterations           | 48         |
# |    time_elapsed         | 239        |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.03493865 |
# |    clip_fraction        | 0.345      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.55      |
# |    explained_variance   | 0.463      |
# |    learning_rate        | 0.001      |
# |    loss                 | 3.63       |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.0716    |
# |    value_loss           | 14.6       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 205        |
# |    iterations           | 49         |
# |    time_elapsed         | 244        |
# |    total_timesteps      | 50176      |
# | train/                  |            |
# |    approx_kl            | 0.03543131 |
# |    clip_fraction        | 0.356      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.53      |
# |    explained_variance   | 0.306      |
# |    learning_rate        | 0.001      |
# |    loss                 | 6.53       |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.0767    |
# |    value_loss           | 22.1       |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 205       |
# |    iterations           | 50        |
# |    time_elapsed         | 248       |
# |    total_timesteps      | 51200     |
# | train/                  |           |
# |    approx_kl            | 0.0446582 |
# |    clip_fraction        | 0.384     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.49     |
# |    explained_variance   | 0.301     |
# |    learning_rate        | 0.001     |
# |    loss                 | 7.3       |
# |    n_updates            | 490       |
# |    policy_gradient_loss | -0.077    |
# |    value_loss           | 15.9      |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 205        |
# |    iterations           | 51         |
# |    time_elapsed         | 254        |
# |    total_timesteps      | 52224      |
# | train/                  |            |
# |    approx_kl            | 0.04169692 |
# |    clip_fraction        | 0.395      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.44      |
# |    explained_variance   | 0.33       |
# |    learning_rate        | 0.001      |
# |    loss                 | 8.09       |
# |    n_updates            | 500        |
# |    policy_gradient_loss | -0.0812    |
# |    value_loss           | 19.2       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 52          |
# |    time_elapsed         | 259         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.039203916 |
# |    clip_fraction        | 0.377       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.43       |
# |    explained_variance   | 0.293       |
# |    learning_rate        | 0.001       |
# |    loss                 | 7.46        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0736     |
# |    value_loss           | 16.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 206         |
# |    iterations           | 53          |
# |    time_elapsed         | 263         |
# |    total_timesteps      | 54272       |
# | train/                  |             |
# |    approx_kl            | 0.053842664 |
# |    clip_fraction        | 0.443       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.43       |
# |    explained_variance   | 0.208       |
# |    learning_rate        | 0.001       |
# |    loss                 | 6.39        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0842     |
# |    value_loss           | 14.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 206         |
# |    iterations           | 54          |
# |    time_elapsed         | 268         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.042608134 |
# |    clip_fraction        | 0.416       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.35       |
# |    explained_variance   | -0.106      |
# |    learning_rate        | 0.001       |
# |    loss                 | 7.23        |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.0802     |
# |    value_loss           | 15.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 206         |
# |    iterations           | 55          |
# |    time_elapsed         | 272         |
# |    total_timesteps      | 56320       |
# | train/                  |             |
# |    approx_kl            | 0.057784416 |
# |    clip_fraction        | 0.472       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.33       |
# |    explained_variance   | -0.0162     |
# |    learning_rate        | 0.001       |
# |    loss                 | 4.61        |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.0822     |
# |    value_loss           | 12.9        |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 206       |
# |    iterations           | 56        |
# |    time_elapsed         | 277       |
# |    total_timesteps      | 57344     |
# | train/                  |           |
# |    approx_kl            | 0.0494325 |
# |    clip_fraction        | 0.42      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.26     |
# |    explained_variance   | -0.0574   |
# |    learning_rate        | 0.001     |
# |    loss                 | 4.27      |
# |    n_updates            | 550       |
# |    policy_gradient_loss | -0.0794   |
# |    value_loss           | 14.1      |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 206        |
# |    iterations           | 57         |
# |    time_elapsed         | 282        |
# |    total_timesteps      | 58368      |
# | train/                  |            |
# |    approx_kl            | 0.05191402 |
# |    clip_fraction        | 0.443      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.25      |
# |    explained_variance   | 0.144      |
# |    learning_rate        | 0.001      |
# |    loss                 | 5.36       |
# |    n_updates            | 560        |
# |    policy_gradient_loss | -0.0834    |
# |    value_loss           | 11.2       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 206        |
# |    iterations           | 58         |
# |    time_elapsed         | 287        |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.04664357 |
# |    clip_fraction        | 0.405      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.21      |
# |    explained_variance   | -0.0144    |
# |    learning_rate        | 0.001      |
# |    loss                 | 6.63       |
# |    n_updates            | 570        |
# |    policy_gradient_loss | -0.0791    |
# |    value_loss           | 15.6       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 206        |
# |    iterations           | 59         |
# |    time_elapsed         | 292        |
# |    total_timesteps      | 60416      |
# | train/                  |            |
# |    approx_kl            | 0.05689144 |
# |    clip_fraction        | 0.439      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.18      |
# |    explained_variance   | 0.044      |
# |    learning_rate        | 0.001      |
# |    loss                 | 3.44       |
# |    n_updates            | 580        |
# |    policy_gradient_loss | -0.0859    |
# |    value_loss           | 11.6       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 206        |
# |    iterations           | 60         |
# |    time_elapsed         | 296        |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.06203574 |
# |    clip_fraction        | 0.456      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.17      |
# |    explained_variance   | 0.074      |
# |    learning_rate        | 0.001      |
# |    loss                 | 5.75       |
# |    n_updates            | 590        |
# |    policy_gradient_loss | -0.0858    |
# |    value_loss           | 13.8       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 207        |
# |    iterations           | 61         |
# |    time_elapsed         | 301        |
# |    total_timesteps      | 62464      |
# | train/                  |            |
# |    approx_kl            | 0.04737972 |
# |    clip_fraction        | 0.43       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.13      |
# |    explained_variance   | 0.0233     |
# |    learning_rate        | 0.001      |
# |    loss                 | 4.95       |
# |    n_updates            | 600        |
# |    policy_gradient_loss | -0.0809    |
# |    value_loss           | 12         |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 207         |
# |    iterations           | 62          |
# |    time_elapsed         | 306         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.040930156 |
# |    clip_fraction        | 0.4         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.1        |
# |    explained_variance   | 0.348       |
# |    learning_rate        | 0.001       |
# |    loss                 | 4.08        |
# |    n_updates            | 610         |
# |    policy_gradient_loss | -0.0802     |
# |    value_loss           | 12.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 207         |
# |    iterations           | 63          |
# |    time_elapsed         | 311         |
# |    total_timesteps      | 64512       |
# | train/                  |             |
# |    approx_kl            | 0.051968638 |
# |    clip_fraction        | 0.413       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.07       |
# |    explained_variance   | 0.284       |
# |    learning_rate        | 0.001       |
# |    loss                 | 3.46        |
# |    n_updates            | 620         |
# |    policy_gradient_loss | -0.0773     |
# |    value_loss           | 9.57        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 207        |
# |    iterations           | 64         |
# |    time_elapsed         | 316        |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.05517377 |
# |    clip_fraction        | 0.445      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.07      |
# |    explained_variance   | 0.444      |
# |    learning_rate        | 0.001      |
# |    loss                 | 3.18       |
# |    n_updates            | 630        |
# |    policy_gradient_loss | -0.0764    |
# |    value_loss           | 8.44       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 207         |
# |    iterations           | 65          |
# |    time_elapsed         | 321         |
# |    total_timesteps      | 66560       |
# ...
# |    loss                 | 1.38        |
# |    n_updates            | 760         |
# |    policy_gradient_loss | -0.0778     |
# |    value_loss           | 5.18        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 208         |
# |    iterations           | 78          |
# |    time_elapsed         | 383         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.057557657 |
# |    clip_fraction        | 0.432       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.73       |
# |    explained_variance   | 0.505       |
# |    learning_rate        | 0.001       |
# |    loss                 | 3.04        |
# |    n_updates            | 770         |
# |    policy_gradient_loss | -0.074      |
# |    value_loss           | 8.27        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 208         |
# |    iterations           | 79          |
# |    time_elapsed         | 387         |
# |    total_timesteps      | 80896       |
# | train/                  |             |
# |    approx_kl            | 0.049637675 |
# |    clip_fraction        | 0.407       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.69       |
# |    explained_variance   | 0.316       |
# |    learning_rate        | 0.001       |
# |    loss                 | 2.94        |
# |    n_updates            | 780         |
# |    policy_gradient_loss | -0.0793     |
# |    value_loss           | 10.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 208         |
# |    iterations           | 80          |
# |    time_elapsed         | 393         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.058501218 |
# |    clip_fraction        | 0.405       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.65       |
# |    explained_variance   | 0.636       |
# |    learning_rate        | 0.001       |
# |    loss                 | 1.71        |
# |    n_updates            | 790         |
# |    policy_gradient_loss | -0.0727     |
# |    value_loss           | 6.91        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 208         |
# |    iterations           | 81          |
# |    time_elapsed         | 397         |
# |    total_timesteps      | 82944       |
# | train/                  |             |
# |    approx_kl            | 0.058170058 |
# |    clip_fraction        | 0.402       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.6        |
# |    explained_variance   | 0.482       |
# |    learning_rate        | 0.001       |
# |    loss                 | 2.56        |
# |    n_updates            | 800         |
# |    policy_gradient_loss | -0.0732     |
# |    value_loss           | 7.97        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 209         |
# |    iterations           | 82          |
# |    time_elapsed         | 401         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.069141366 |
# |    clip_fraction        | 0.45        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.6        |
# |    explained_variance   | 0.69        |
# |    learning_rate        | 0.001       |
# |    loss                 | 1.5         |
# |    n_updates            | 810         |
# |    policy_gradient_loss | -0.0784     |
# |    value_loss           | 5.37        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 208         |
# |    iterations           | 83          |
# |    time_elapsed         | 406         |
# |    total_timesteps      | 84992       |
# | train/                  |             |
# |    approx_kl            | 0.052862875 |
# |    clip_fraction        | 0.377       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.58       |
# |    explained_variance   | 0.739       |
# |    learning_rate        | 0.001       |
# |    loss                 | 2.85        |
# |    n_updates            | 820         |
# |    policy_gradient_loss | -0.0717     |
# |    value_loss           | 6.38        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 209        |
# |    iterations           | 84         |
# |    time_elapsed         | 411        |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.04835791 |
# |    clip_fraction        | 0.395      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.57      |
# |    explained_variance   | 0.624      |
# |    learning_rate        | 0.001      |
# |    loss                 | 2.87       |
# |    n_updates            | 830        |
# |    policy_gradient_loss | -0.0756    |
# |    value_loss           | 9.1        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 209         |
# |    iterations           | 85          |
# |    time_elapsed         | 415         |
# |    total_timesteps      | 87040       |
# | train/                  |             |
# |    approx_kl            | 0.055311553 |
# |    clip_fraction        | 0.4         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.65       |
# |    explained_variance   | 0.571       |
# |    learning_rate        | 0.001       |
# |    loss                 | 2.09        |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.0708     |
# |    value_loss           | 7.06        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 209        |
# |    iterations           | 86         |
# |    time_elapsed         | 420        |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.06424417 |
# |    clip_fraction        | 0.425      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.6       |
# |    explained_variance   | 0.478      |
# |    learning_rate        | 0.001      |
# |    loss                 | 2.39       |
# |    n_updates            | 850        |
# |    policy_gradient_loss | -0.0755    |
# |    value_loss           | 7.18       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 209         |
# |    iterations           | 87          |
# |    time_elapsed         | 425         |
# |    total_timesteps      | 89088       |
# | train/                  |             |
# |    approx_kl            | 0.046880797 |
# |    clip_fraction        | 0.36        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.57       |
# |    explained_variance   | 0.554       |
# |    learning_rate        | 0.001       |
# |    loss                 | 2.26        |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.0717     |
# |    value_loss           | 8.97        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 209         |
# |    iterations           | 88          |
# |    time_elapsed         | 430         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.059164133 |
# |    clip_fraction        | 0.415       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.55       |
# |    explained_variance   | 0.725       |
# |    learning_rate        | 0.001       |
# |    loss                 | 1.54        |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.0754     |
# |    value_loss           | 5.51        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 209         |
# |    iterations           | 89          |
# |    time_elapsed         | 434         |
# |    total_timesteps      | 91136       |
# | train/                  |             |
# |    approx_kl            | 0.050979033 |
# |    clip_fraction        | 0.386       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.52       |
# |    explained_variance   | 0.667       |
# |    learning_rate        | 0.001       |
# |    loss                 | 1.99        |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.0727     |
# |    value_loss           | 6.21        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 209        |
# |    iterations           | 90         |
# |    time_elapsed         | 439        |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.04854016 |
# |    clip_fraction        | 0.381      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.56      |
# |    explained_variance   | 0.689      |
# |    learning_rate        | 0.001      |
# |    loss                 | 2.41       |
# |    n_updates            | 890        |
# |    policy_gradient_loss | -0.0679    |
# |    value_loss           | 7.28       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 209        |
# |    iterations           | 91         |
# |    time_elapsed         | 444        |
# |    total_timesteps      | 93184      |
# | train/                  |            |
# |    approx_kl            | 0.05773803 |
# |    clip_fraction        | 0.388      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.53      |
# |    explained_variance   | 0.686      |
# |    learning_rate        | 0.001      |
# |    loss                 | 2.54       |
# |    n_updates            | 900        |
# |    policy_gradient_loss | -0.0778    |
# |    value_loss           | 8.59       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 210        |
# |    iterations           | 92         |
# |    time_elapsed         | 448        |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.05106653 |
# |    clip_fraction        | 0.406      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.53      |
# |    explained_variance   | 0.729      |
# |    learning_rate        | 0.001      |
# |    loss                 | 1.71       |
# |    n_updates            | 910        |
# |    policy_gradient_loss | -0.0756    |
# |    value_loss           | 6.53       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 210         |
# |    iterations           | 93          |
# |    time_elapsed         | 453         |
# |    total_timesteps      | 95232       |
# | train/                  |             |
# |    approx_kl            | 0.059758596 |
# |    clip_fraction        | 0.406       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.49       |
# |    explained_variance   | 0.771       |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.905       |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.074      |
# |    value_loss           | 4.72        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 209         |
# |    iterations           | 94          |
# |    time_elapsed         | 458         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.053531274 |
# |    clip_fraction        | 0.379       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | 0.749       |
# |    learning_rate        | 0.001       |
# |    loss                 | 1.29        |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.0678     |
# |    value_loss           | 5.49        |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 210       |
# |    iterations           | 95        |
# |    time_elapsed         | 462       |
# |    total_timesteps      | 97280     |
# | train/                  |           |
# |    approx_kl            | 0.0682757 |
# |    clip_fraction        | 0.402     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.44     |
# |    explained_variance   | 0.817     |
# |    learning_rate        | 0.001     |
# |    loss                 | 1.93      |
# |    n_updates            | 940       |
# |    policy_gradient_loss | -0.0722   |
# |    value_loss           | 4         |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 210        |
# |    iterations           | 96         |
# |    time_elapsed         | 467        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.04194162 |
# |    clip_fraction        | 0.351      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.42      |
# |    explained_variance   | 0.729      |
# |    learning_rate        | 0.001      |
# |    loss                 | 3.15       |
# |    n_updates            | 950        |
# |    policy_gradient_loss | -0.0664    |
# |    value_loss           | 7.96       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 210        |
# |    iterations           | 97         |
# |    time_elapsed         | 472        |
# |    total_timesteps      | 99328      |
# | train/                  |            |
# |    approx_kl            | 0.06872626 |
# |    clip_fraction        | 0.404      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.4       |
# |    explained_variance   | 0.82       |
# |    learning_rate        | 0.001      |
# |    loss                 | 1.46       |
# |    n_updates            | 960        |
# |    policy_gradient_loss | -0.0707    |
# |    value_loss           | 4.62       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 210         |
# |    iterations           | 98          |
# |    time_elapsed         | 476         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.047417782 |
# |    clip_fraction        | 0.357       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.756       |
# |    learning_rate        | 0.001       |
# |    loss                 | 1.89        |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.0685     |
# |    value_loss           | 6.63        |
# -----------------------------------------
# ✅ Total reward from real-time reallocation: 42.0

# %%
# Test agent
# Test agent & collect reassignment results
obs, _ = env.reset()
total_reward = 0
reassigned_flights = []

while True:
    action, _ = model.predict(obs)
    obs, reward, terminated, truncated, _ = env.step(action)
    total_reward += reward

    # Collect reallocation info
    if env.current_idx <= env.num_flights:
        flight_row = env.flights_df.iloc[env.current_idx - 1]  # current flight
        assigned_gate = flight_row["Assigned_Gate"] if action == env.num_gates else env.gates_df.iloc[action]["Gate_ID"]
        stand_id = assigned_gate if assigned_gate in env.stand_usage else env.remote_gate_map.get(assigned_gate, None)

        reassigned_flights.append({
            "Flight_ID": flight_row["Flight_ID"],
            "Assigned_Gate_Reassigned": assigned_gate,
            "Assigned_Stand_Reassigned": stand_id,
            "Reward": reward  # Add reward here
        })

    if terminated or truncated:
        break

print(f"✅ Total reward from real-time reallocation: {total_reward}")

# Convert collected info to reassigned_df
reassigned_df = pd.DataFrame(reassigned_flights)
# Out:
# ✅ Total reward from real-time reallocation: 47.5

# %%
import pandas as pd

# 1. Merge reassignment results and rewards into the original flights dataframe
full_df = flights_df.copy()
full_df = full_df.merge(
    reassigned_df[['Flight_ID', 'Assigned_Gate_Reassigned', 'Assigned_Stand_Reassigned', 'Reward']],
    on='Flight_ID',
    how='left'
)

# 2. Check whether reassignment occurred (either gate or stand changed)
def was_reassigned(row):
    return int(
        row['Assigned_Gate'] != row['Assigned_Gate_Reassigned'] or
        row['Assigned_Stand'] != row['Assigned_Stand_Reassigned']
    )

full_df['Reassigned'] = full_df.apply(was_reassigned, axis=1)

# 3. Summary statistics
total_flights = len(full_df)
total_reassigned = full_df['Reassigned'].sum()
reassignment_rate = total_reassigned / total_flights * 100 if total_flights else 0

print(f"Total Flights: {total_flights}")
print(f"Reassigned Flights: {total_reassigned}")
print(f"Reassignment Rate (All Flights): {reassignment_rate:.2f}%")

# 4. Preview a sample of the results
print("\nSample of all flights with reassignment and reward info:")
print(full_df[['Flight_ID', 'Assigned_Gate', 'Assigned_Gate_Reassigned', 'Reassigned', 'Reward']].head())

# 5. Export full results to CSV
full_df.to_csv("all_flight_reassignment_analysis.csv", index=False)
print("✅ CSV file saved as 'all_flight_reassignment_analysis.csv'")
# Out:
# Total Flights: 100
# Reassigned Flights: 96
# Reassignment Rate (All Flights): 96.00%
#
# Sample of all flights with reassignment and reward info:
#   Flight_ID Assigned_Gate Assigned_Gate_Reassigned  Reassigned  Reward
# 0    CA4157           G01                      G04           1     0.5
# 1    CA4420           G02                      G08           1     0.5
# 2    ZH5380           G03                      G03           1     1.0
# 3    CA3491           G04                      G12           1     0.5
# 4    MU7316           G05                      G02           1     0.5
# ✅ CSV file saved as 'all_flight_reassignment_analysis.csv'
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:151: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
def evaluate_model(model, env, num_runs=10):
    total_rewards = []
    all_reassigned = []

    for run in range(num_runs):
        obs, _ = env.reset()
        run_reward = 0
        reassigned_flights = []

        while True:
            action, _ = model.predict(obs)
            obs, reward, terminated, truncated, _ = env.step(action)
            run_reward += reward

            if env.current_idx <= env.num_flights:
                flight_row = env.flights_df.iloc[env.current_idx - 1]
                assigned_gate = (
                    flight_row["Assigned_Gate"]
                    if action == env.num_gates
                    else env.gates_df.iloc[action]["Gate_ID"]
                )
                stand_id = (
                    assigned_gate
                    if assigned_gate in env.stand_usage
                    else env.remote_gate_map.get(assigned_gate, None)
                )

                reassigned_flights.append({
                    "Run": run + 1,
                    "Flight_ID": flight_row["Flight_ID"],
                    "Assigned_Gate_Reassigned": assigned_gate,
                    "Assigned_Stand_Reassigned": stand_id,
                    "Reward": reward
                })

            if terminated or truncated:
                break

        total_rewards.append(run_reward)
        all_reassigned.extend(reassigned_flights)

        print(f"Run {run+1}: Reward = {run_reward:.2f}")

    avg_reward = np.mean(total_rewards)
    print(f"\n✅ Average reward over {num_runs} runs: {avg_reward:.2f}")

    reassigned_df = pd.DataFrame(all_reassigned)
    return reassigned_df, total_rewards

# For example, repeatedly evaluate the PPO model 10 times
reassigned_df, rewards = evaluate_model(model, env, num_runs=10)
# Out:
# Run 1: Reward = 38.50
# Run 2: Reward = 31.50
# Run 3: Reward = 42.00
# Run 4: Reward = 47.00
# Run 5: Reward = 37.00
# Run 6: Reward = 36.00
# Run 7: Reward = 41.50
# Run 8: Reward = 42.50
# Run 9: Reward = 42.00
# Run 10: Reward = 36.50
#
# ✅ Average reward over 10 runs: 39.45
